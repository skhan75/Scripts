# %%
def countingSort(A):
    
    minimum = A[0]
    maximum = A[0]
    
    #Find mimimum and maximum for range of index
    for i in A:
        if(i < minimum):
            minimum = i
        if(i > maximum):
            maximum = i
    
    print ('Minimum Element: ', minimum)
    print ('Maximum Element: ', maximum)  
    
    index = []
    count = [0] * (maximum + 1)
    
    
    for i in range(minimum, maximum):
        count[i] = 0 
        
    #Count occurences of each no in array 
    for i in A:
        count[A[i]] += 1
        
    
    
    
    
    count_array = [minimum, maximum]
    j = minimum
    
    for i in range(minimum, maximum):
        if(i == ):
            count_array[i] = count[A[j]]

# %%
countingSort([2,45,1,5,2,4,7,8])
# Out:
# Minimum Element:  1
# Maximum Element:  45
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-8df4313a61f8> in <module>()
# ----> 1 countingSort([2,45,1,5,2,4,7,8])
#
# <ipython-input-38-4a24be6f8d2b> in countingSort(A)
#      21
#      22     for i in A:
# ---> 23         count[A[i]] += 1
#      24
#      25     j = 1
#
# IndexError: list index out of range
